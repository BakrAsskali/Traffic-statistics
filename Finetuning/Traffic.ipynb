# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# !cd darknet && make
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ...

# %%
import os

# Define paths (update these to your actual paths in Google Drive)
data_dir = '5jcg5vfx58-3/Videos_1/Annotation_Videos_1/Annotation_Videos_1_yolo_1.1'  # replace 'your_data_folder'
obj_data_path = os.path.join(data_dir, 'obj.data')
obj_names_path = os.path.join(data_dir, 'obj.names')
train_txt_path = os.path.join(data_dir, 'train.txt')
frames_folder_path = os.path.join(data_dir, 'obj_train_data')


# Check if the files and folder exist
if not os.path.exists(obj_data_path):
    raise FileNotFoundError(f"obj.data not found at {obj_data_path}")
if not os.path.exists(obj_names_path):
    raise FileNotFoundError(f"obj.names not found at {obj_names_path}")
if not os.path.exists(train_txt_path):
    raise FileNotFoundError(f"train.txt not found at {train_txt_path}")
if not os.path.exists(frames_folder_path):
    raise FileNotFoundError(f"frames folder not found at {frames_folder_path}")


# Example usage (replace with your actual processing logic)
print(f"obj.data path: {obj_data_path}")
print(f"obj.names path: {obj_names_path}")
print(f"train.txt path: {train_txt_path}")
print(f"frames folder path: {frames_folder_path}")

# Configuration
cfg_file = 'yolov3.cfg'  # Update with your .cfg file path
weights_file = 'yolov3.weights'  # Update with your .weights file path

# Darknet training command
# !./darknet/darknet detector train {obj_data_path} {cfg_file} {weights_file} -dont_show
# Out:
# obj.data path: 5jcg5vfx58-3/Videos_1/Annotation_Videos_1/Annotation_Videos_1_yolo_1.1/obj.data
# obj.names path: 5jcg5vfx58-3/Videos_1/Annotation_Videos_1/Annotation_Videos_1_yolo_1.1/obj.names
# train.txt path: 5jcg5vfx58-3/Videos_1/Annotation_Videos_1/Annotation_Videos_1_yolo_1.1/train.txt
# frames folder path: 5jcg5vfx58-3/Videos_1/Annotation_Videos_1/Annotation_Videos_1_yolo_1.1/obj_train_data
#  GPU isn't used
#  OpenCV isn't used - data augmentation will be slow
# yolov3
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
# ...
